# %% [markdown]
# Using word embedding models to study long-term language change

# %% [markdown]
# Importing packages

# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %%
from lxml import html
page = requests.get("https://en.wikisource.org/wiki/Portal:Exploration")
tree = html.fromstring(page.content)
print(tree)
# Out:
# <Element html at 0x2d13f290908>

# %% [markdown]
# Extract raw text from a page

# %%
import urllib.request

html1 = urllib.request.urlopen("https://en.wikisource.org/wiki/Portal:Exploration")
raw1 = html1.read()
print(raw1)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Exploration - Wikisource, the free online library</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"Portal","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":100,"wgPageName":"Portal:Exploration","wgTitle":"Exploration","wgCurRevisionId":6904779,"wgRevisionId":6904779,"wgArticleId":593015,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Portals needing review","Geo-anthropology portals","Portals","Exploration"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","
# ...

# %% [markdown]
# length of raw text

# %%
len(raw1)
# Out:
# 65649

# %% [markdown]
# using beautiful soup for a better representation of raw text

# %%
url1 = raw1
soup = BeautifulSoup(raw1, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Exploration - Wikisource, the free online library</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...

# %%
len(soup)
# Out:
# 1

# %% [markdown]
# extract all <a's

# %%
soup.findAll('a')
# Out:
# [<a id="top"></a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#p-search">Jump to search</a>,
#  <a href="/wiki/Portal:Geography,_Anthropology_and_Recreation" title="Portal:Geography, Anthropology and Recreation">Geography, Anthropology and Recreation</a>,
#  <a href="/wiki/Portal:Geography,_Anthropology_and_Recreation" title="Portal:Geography, Anthropology and Recreation">G</a>,
#  <a href="/wiki/Portal:Portals" title="Portal:Portals">Main</a>,
#  <a href="/wiki/Portal:Index" title="Portal:Index">Index</a>,
# ...

# %%
one_a_tag1 = soup.findAll('a')[1]
link1 = one_a_tag1['href']

# %%
time.sleep(1)

# %%
from lxml import html
page1 = requests.get("https://en.wikisource.org/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah")
tree1 = html.fromstring(page1.content)

# %%
import urllib.request

html2 = urllib.request.urlopen("https://en.wikisource.org/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah")
raw2 = html2.read()
print(raw2)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Personal Narrative of a Pilgrimage to Al Madinah and Meccah - Wikisource, the free online library</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah","wgTitle":"Personal Narrative of a Pilgrimage to Al Madinah and Meccah","wgCurRevisionId":3800756,"wgRevisionId":3800756,"wgArticleId":131371,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Saudi Arabia"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable
# ...

# %%
url2 = raw2
soup1 = BeautifulSoup(raw2, 'html.parser')

# %%
soup1.findAll('a')
# Out:
# [<a id="top"></a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#p-search">Jump to search</a>,
#  <a href="/wiki/Author:Richard_Francis_Burton" title="Author:Richard Francis Burton"><span class="vcard" id="header_author_text"><span class="fn">Richard Francis Burton</span></span></a>,
#  <a href="/wiki/Special:SiteMatrix" title="Special:SiteMatrix"><img alt="Sister Projects." data-file-height="1024" data-file-width="1024" decoding="async" height="18" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/81/Wikimedia-logo.svg/18px-Wikimedia-logo.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/81/Wikimedia-logo.svg/27px-Wikimedia-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/81/Wikimedia-logo.svg/36px-Wikimedia-logo.svg.png 2x" width="18"/></a>,
#  <a href="/wiki/Special:SiteMatrix" title="Special:SiteMatrix">sister projects</a>,
# ...

# %%
one_a_tag2 = soup1.findAll('a')[1]
link2 = one_a_tag2['href']

# %%
from lxml import html
page2 = requests.get("https://en.wikisource.org/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah/Volume_I")
tree2 = html.fromstring(page2.content)

# %%
import urllib.request

html3 = urllib.request.urlopen("https://en.wikisource.org/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah/Volume_I")
raw3 = html3.read()
print(raw3)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Personal Narrative of a Pilgrimage to Al Madinah and Meccah/Volume I - Wikisource, the free online library</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah/Volume_I","wgTitle":"Personal Narrative of a Pilgrimage to Al Madinah and Meccah/Volume I","wgCurRevisionId":4860207,"wgRevisionId":4860207,"wgArticleId":131494,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Subpages"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""]
# ...

# %%
url3 = raw3
soup2 = BeautifulSoup(raw3, 'html.parser')

# %%
soup2.findAll('a')
# Out:
# [<a id="top"></a>,
#  <a href="/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah" title="Personal Narrative of a Pilgrimage to Al Madinah and Meccah">Personal Narrative of a Pilgrimage to Al Madinah and Meccah</a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#p-search">Jump to search</a>,
#  <a href="/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah" title="Personal Narrative of a Pilgrimage to Al Madinah and Meccah">Personal Narrative of a Pilgrimage to Al Madinah and Meccah</a>,
#  <a href="/wiki/Author:Richard_Francis_Burton" title="Author:Richard Francis Burton"><span class="vcard" id="header_author_text"><span class="fn">Richard Francis Burton</span></span></a>,
#  <a href="/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah/Volume_II" title="Personal Narrative of a Pilgrimage to Al Madinah and Meccah/Volume II">Volume II</a>,
# ...

# %%
one_a_tag3 = soup2.findAll('a')[1]
link3 = one_a_tag3['href']

# %%
page3 = requests.get("https://en.wikisource.org/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah/Volume_II")
tree3 = html.fromstring(page3.content)

# %%
html4 = urllib.request.urlopen("https://en.wikisource.org/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah/Volume_II")
raw4 = html4.read()
print(raw4)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Personal Narrative of a Pilgrimage to Al Madinah and Meccah/Volume II - Wikisource, the free online library</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah/Volume_II","wgTitle":"Personal Narrative of a Pilgrimage to Al Madinah and Meccah/Volume II","wgCurRevisionId":3800834,"wgRevisionId":3800834,"wgArticleId":131495,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Subpages","PD-1923","Illustration","Mosques","Blueprints"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentMo
# ...

# %%
url4 = raw4
soup3 = BeautifulSoup(raw4, 'html.parser')
soup3.findAll('a')
# Out:
# [<a id="top"></a>,
#  <a href="/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah" title="Personal Narrative of a Pilgrimage to Al Madinah and Meccah">Personal Narrative of a Pilgrimage to Al Madinah and Meccah</a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#p-search">Jump to search</a>,
#  <a href="/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah/Volume_I" title="Personal Narrative of a Pilgrimage to Al Madinah and Meccah/Volume I">Volume I</a>,
#  <a href="/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah" title="Personal Narrative of a Pilgrimage to Al Madinah and Meccah">Personal Narrative of a Pilgrimage to Al Madinah and Meccah</a>,
#  <a href="/wiki/Author:Richard_Francis_Burton" title="Author:Richard Francis Burton"><span class="vcard" id="header_author_text"><span class="fn">Richard Francis Burton</span></span></a>,
# ...

# %%
one_a_tag4 = soup3.findAll('a')[1]
link4 = one_a_tag4['href']

# %%
page4 = requests.get("https://en.wikisource.org/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah/Volume_III")
tree4 = html.fromstring(page4.content)

# %%
html5 = urllib.request.urlopen("https://en.wikisource.org/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah/Volume_III")
raw5 = html5.read()
print(raw5)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Personal Narrative of a Pilgrimage to Al Madinah and Meccah/Volume III - Wikisource, the free online library</title>\n<script>document.documentElement.className = document.documentElement.className.replace( /(^|\\s)client-nojs(\\s|$)/, "$1client-js$2" );</script>\n<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah/Volume_III","wgTitle":"Personal Narrative of a Pilgrimage to Al Madinah and Meccah/Volume III","wgCurRevisionId":3800956,"wgRevisionId":3800956,"wgArticleId":131672,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Subpages"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":[
# ...

# %%
url5 = raw5
soup4 = BeautifulSoup(raw5, 'html.parser')
soup4.findAll('a')
# Out:
# [<a id="top"></a>,
#  <a href="/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah" title="Personal Narrative of a Pilgrimage to Al Madinah and Meccah">Personal Narrative of a Pilgrimage to Al Madinah and Meccah</a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#p-search">Jump to search</a>,
#  <a href="/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah/Volume_II" title="Personal Narrative of a Pilgrimage to Al Madinah and Meccah/Volume II">Volume II</a>,
#  <a href="/wiki/Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah" title="Personal Narrative of a Pilgrimage to Al Madinah and Meccah">Personal Narrative of a Pilgrimage to Al Madinah and Meccah</a>,
#  <a href="/wiki/Author:Richard_Francis_Burton" title="Author:Richard Francis Burton"><span class="vcard" id="header_author_text"><span class="fn">Richard Francis Burton</span></span></a>,
# ...

# %%
one_a_tag5 = soup4.findAll('a')[1]
link5 = one_a_tag5['href']

# %%
#import nltk   
#import urlopen
#raw6 = nltk.clean_html(html1)
#tokens = nltk.word_tokenize(raw6)
#tokens

# %%
from bs4 import BeautifulSoup

# Create a BeautifulSoup object from the HTML
soup6 = BeautifulSoup(raw1, "html5lib")
type(soup6)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# getting title of page

# %%
soup6.title
# Out:
# <title>Exploration - Wikisource, the free online library</title>

# %% [markdown]
# title in string format

# %%
soup6.title.string
# Out:
# 'Exploration - Wikisource, the free online library'

# %%
soup6.findAll('a')[:20]
# Out:
# [<a id="top"></a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#p-search">Jump to search</a>,
#  <a href="/wiki/Portal:Geography,_Anthropology_and_Recreation" title="Portal:Geography, Anthropology and Recreation">Geography, Anthropology and Recreation</a>,
#  <a href="/wiki/Portal:Geography,_Anthropology_and_Recreation" title="Portal:Geography, Anthropology and Recreation">G</a>,
#  <a href="/wiki/Portal:Portals" title="Portal:Portals">Main</a>,
#  <a href="/wiki/Portal:Index" title="Portal:Index">Index</a>,
# ...

# %% [markdown]
# clean text using beautifulsoup

# %%
text = soup6.get_text()
len(text)
# Out:
# 14094

# %%
print(text)
# Out:
# Exploration - Wikisource, the free online library
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
# ...

# %% [markdown]
# tokens from clean text

# %%
text_tokens = nltk.tokenize.word_tokenize(text)
print (text_tokens)
# Out:
# ['Exploration', '-', 'Wikisource', ',', 'the', 'free', 'online', 'library', 'document.documentElement.className', '=', 'document.documentElement.className.replace', '(', '/', '(', '^|\\s', ')', 'client-nojs', '(', '\\s|', '$', ')', '/', ',', '``', '$', '1client-js', '$', '2', "''", ')', ';', '(', 'window.RLQ=window.RLQ||', '[', ']', ')', '.push', '(', 'function', '(', ')', '{', 'mw.config.set', '(', '{', '``', 'wgCanonicalNamespace', "''", ':', "''", 'Portal', "''", ',', "''", 'wgCanonicalSpecialPageName', "''", ':', 'false', ',', "''", 'wgNamespaceNumber', "''", ':100', ',', "''", 'wgPageName', "''", ':', "''", 'Portal', ':', 'Exploration', "''", ',', "''", 'wgTitle', "''", ':', "''", 'Exploration', "''", ',', "''", 'wgCurRevisionId', "''", ':6904779', ',', "''", 'wgRevisionId', "''", ':6904779', ',', "''", 'wgArticleId', "''", ':593015', ',', "''", 'wgIsArticle', "''", ':', 'true', ',', "''", 'wgIsRedirect', "''", ':', 'false', ',', "''", 'wgAction', "''", ':', "''", 'view', "''", 
# ...

# %% [markdown]
# removing puncation from tokens

# %%
import re
import string
text_tokens = [t for t in text_tokens if not re.match('[' + string.punctuation + ']+', t)]
print(text_tokens)
# Out:
# ['Exploration', 'Wikisource', 'the', 'free', 'online', 'library', 'document.documentElement.className', 'document.documentElement.className.replace', 'client-nojs', '\\s|', '1client-js', '2', 'window.RLQ=window.RLQ||', 'function', 'mw.config.set', 'wgCanonicalNamespace', 'Portal', 'wgCanonicalSpecialPageName', 'false', 'wgNamespaceNumber', 'wgPageName', 'Portal', 'Exploration', 'wgTitle', 'Exploration', 'wgCurRevisionId', 'wgRevisionId', 'wgArticleId', 'wgIsArticle', 'true', 'wgIsRedirect', 'false', 'wgAction', 'view', 'wgUserName', 'null', 'wgUserGroups', 'wgCategories', 'Portals', 'needing', 'review', 'Geo-anthropology', 'portals', 'Portals', 'Exploration', 'wgBreakFrames', 'false', 'wgPageContentLanguage', 'en', 'wgPageContentModel', 'wikitext', 'wgSeparatorTransformTable', 'wgDigitTransformTable', 'wgDefaultDateFormat', 'dmy', 'wgMonthNames', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'wgMonthNamesShor
# ...

# %% [markdown]
# length of tokens

# %%
len(text_tokens)
# Out:
# 1554

# %% [markdown]
# unique tokens from clean text

# %%
no_order = list(set(text_tokens))
print(no_order)
# Out:
# ['1855', 'Stein', 'function', 'veswitched', 'journeys', 'Wikipedia', 'wgRestrictionMove', 'Space', 'Districts', 'Joseph', 'L.', 'Nicaragua', '1883', 'Discoveries', 'editToken', 'from', 'Namespaces', 'July', 'changesSubject', 'mw.loader.implement', '12', 'Wikidata', 'Zambesi', 'showcount\\', 'Mar', 'East', 'Tributaries', '1789', 'wgBackendResponseTime', 'Portal', 'License', 'David', 'Pedrarias', 'portalsPortalsExplorationHidden', 'espanol', 'Exploration', 'Jump', 'Cook', 'Country', 'free', 'Arizona', 'Continuation', '1772', 'Sending', '1877', '9', 'Theodore', 'Kennedy', 'Spiers', 'wgMFDisplayWikibaseDescriptions', 'Antarctic', '1875', '1881-84', 'hideprefix\\', 'Hugh', '1914', 'ext.eventLogging', '45', 'Tafilet', '1788', 'Mungo', 'Results', 'voyage', 'Mount', 'Geography', '0tffind', 'postexpandincludesize', 'English', 'ext.uls.interface', 'Wright', 'Andersson', 'or', '1836—39', '1876', 'require', 'mmv.bootstrap.autostart', 'as', 'Reade', 'Policy', 'Gustav', 's', 'Patrick', 'edition', 
# ...

# %% [markdown]
# length of unique tokens

# %%
len(no_order)
# Out:
# 814

# %%
soup7 = BeautifulSoup(raw2, "html5lib")
type(soup7)
# Out:
# bs4.BeautifulSoup

# %%
soup7.title
# Out:
# <title>Personal Narrative of a Pilgrimage to Al Madinah and Meccah - Wikisource, the free online library</title>

# %%
soup7.title.string
# Out:
# 'Personal Narrative of a Pilgrimage to Al Madinah and Meccah - Wikisource, the free online library'

# %%
soup7.findAll('a')[:20]
# Out:
# [<a id="top"></a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#p-search">Jump to search</a>,
#  <a href="/wiki/Author:Richard_Francis_Burton" title="Author:Richard Francis Burton"><span class="vcard" id="header_author_text"><span class="fn">Richard Francis Burton</span></span></a>,
#  <a href="/wiki/Special:SiteMatrix" title="Special:SiteMatrix"><img alt="Sister Projects." data-file-height="1024" data-file-width="1024" decoding="async" height="18" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/81/Wikimedia-logo.svg/18px-Wikimedia-logo.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/81/Wikimedia-logo.svg/27px-Wikimedia-logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/81/Wikimedia-logo.svg/36px-Wikimedia-logo.svg.png 2x" width="18"/></a>,
#  <a href="/wiki/Special:SiteMatrix" title="Special:SiteMatrix">sister projects</a>,
# ...

# %%
text1 = soup7.get_text()
len(text1)
# Out:
# 7668

# %%
print(text1)
# Out:
# Personal Narrative of a Pilgrimage to Al Madinah and Meccah - Wikisource, the free online library
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
# ...

# %%
text_tokens1 = nltk.tokenize.word_tokenize(text1)
print (text_tokens1)
# Out:
# ['Personal', 'Narrative', 'of', 'a', 'Pilgrimage', 'to', 'Al', 'Madinah', 'and', 'Meccah', '-', 'Wikisource', ',', 'the', 'free', 'online', 'library', 'document.documentElement.className', '=', 'document.documentElement.className.replace', '(', '/', '(', '^|\\s', ')', 'client-nojs', '(', '\\s|', '$', ')', '/', ',', '``', '$', '1client-js', '$', '2', "''", ')', ';', '(', 'window.RLQ=window.RLQ||', '[', ']', ')', '.push', '(', 'function', '(', ')', '{', 'mw.config.set', '(', '{', '``', 'wgCanonicalNamespace', "''", ':', "''", "''", ',', "''", 'wgCanonicalSpecialPageName', "''", ':', 'false', ',', "''", 'wgNamespaceNumber', "''", ':0', ',', "''", 'wgPageName', "''", ':', "''", 'Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah', "''", ',', "''", 'wgTitle', "''", ':', "''", 'Personal', 'Narrative', 'of', 'a', 'Pilgrimage', 'to', 'Al', 'Madinah', 'and', 'Meccah', "''", ',', "''", 'wgCurRevisionId', "''", ':3800756', ',', "''", 'wgRevisionId', "''", ':3800756', ',', "''", 'wgArti
# ...

# %%
len(text_tokens1)
# Out:
# 555

# %%
import re
import string
text_tokens1 = [t for t in text_tokens1 if not re.match('[' + string.punctuation + ']+', t)]
print(text_tokens1)
# Out:
# ['Personal', 'Narrative', 'of', 'a', 'Pilgrimage', 'to', 'Al', 'Madinah', 'and', 'Meccah', 'Wikisource', 'the', 'free', 'online', 'library', 'document.documentElement.className', 'document.documentElement.className.replace', 'client-nojs', '\\s|', '1client-js', '2', 'window.RLQ=window.RLQ||', 'function', 'mw.config.set', 'wgCanonicalNamespace', 'wgCanonicalSpecialPageName', 'false', 'wgNamespaceNumber', 'wgPageName', 'Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah', 'wgTitle', 'Personal', 'Narrative', 'of', 'a', 'Pilgrimage', 'to', 'Al', 'Madinah', 'and', 'Meccah', 'wgCurRevisionId', 'wgRevisionId', 'wgArticleId', 'wgIsArticle', 'true', 'wgIsRedirect', 'false', 'wgAction', 'view', 'wgUserName', 'null', 'wgUserGroups', 'wgCategories', 'Saudi', 'Arabia', 'wgBreakFrames', 'false', 'wgPageContentLanguage', 'en', 'wgPageContentModel', 'wikitext', 'wgSeparatorTransformTable', 'wgDigitTransformTable', 'wgDefaultDateFormat', 'dmy', 'wgMonthNames', 'January', 'February', 'March',
# ...

# %%
len(text_tokens1)
# Out:
# 555

# %%
no_order1 = list(set(text_tokens1))
print(no_order1)
# Out:
# ['1855', 'function', 'Personal_Narrative_of_a_Pilgrimage_to_Al_Madinah_and_Meccah', 'veswitched', 'wgRestrictionMove', 'mw1305', 'from', 'editToken', 'Namespaces', 'July', 'changesSubject', 'mw.loader.implement', 'Wikidata', 'I.', 'showcount\\', 'Mar', 'wgBackendResponseTime', 'License', 'espanol', 'Jump', 'free', 'itemCite', 'wgMFDisplayWikibaseDescriptions', 'hideprefix\\', 'ext.eventLogging', '0tffind', 'postexpandincludesize', 'English', 'ext.uls.interface', 'MeccahRichard', 'require', 'mmv.bootstrap.autostart', 'as', 'Policy', 'wgCentralNoticeCookiesToDelete', 'catalan', 'window.RLQ=window.RLQ||', 'book', 'Retrieved', 'templateargumentsize', 'mediawiki.skinning.interface', 'Download/print', 'Terms', 'portalCentral', 'limitreport-memusage', 'library', 'a', 'user.styles', 'West-Vlams', 'limit', 'transcriptionHelpDonate', 'this', '\\', 'wgIsRedirect', 'languages', 'ttl', 'From', 'Use', 'Third', 'May', 'other', 'and', 'hereRelated', 'agree', 'null', 'ext.gadget.charinsert', 'search'
# ...

# %%
len(no_order1)
# Out:
# 384
